# %%
print(" Umer")
# Out:
#  Umer

# %%
fruits: list=['apple',"banana","chary"]
print(fruits)
# Out:
# ['apple', 'banana', 'chary']

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-2]
# Out:
# 'banana'

# %%
fruits[1:4]
# Out:
# ['banana', 'chary']

# %%
for items in fruits:
    if items in fruits < 2:
        fruits.remove()
    else:
        print(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 for items in fruits:
# ----> 2     if items in fruits < 2:
#       3         fruits.remove()
#       4     else:
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
fruits: list=['apple',"banana","chary"]
size=len(fruits)
print(size)
if size > 2:
    fruits.pop()
print(fruits)
# Out:
# 3
# ['apple', 'banana']

# %%
n=int(input("Please Enter The Number You Want to Calculate Factorial"))
def calc_fac(n):
    fac=1
    for i in range(1,n+1):
        fac=fac*i
    print(fac)
calc_fac(n)
# Out:
# 720

# %%
def currency_calc(value):
    pkr=280
    doller=pkr*value
    print(doller)

doler=int(input("Please Enter The currancy in doller"))
currency_calc(doler)
# Out:
# 1960

# %%
class StoreInventory:
    def __init__(self):
        self.inventory={}

    def add_items(self,item,quantity):
        if item in self.inventory:
            print(f"{item} is already exists in inventory")
        else:
            self.inventory[item]= quantity
            print(f"Item: {item} is Added with quantity: {quantity}")

    def update_quantity(self,item,quantity):
        if item in self.inventory:
            self.inventory[item]=quantity
            print(f"Item: {item} is updated quantity to {quantity}")
        else:
            print("Item does not exists")

    def del_item(self,item):
        if item in self.inventory:
            del self.inventory[item]
            print(f"Item: {item} deleted successfully")
        else:
            print("Item does not exists")

    def display_inventory(self):
        for item,quantity in self.inventory.items():
            print(f"Store Inventory\n -{item} : {quantity}")


def main():
    inventory=StoreInventory()
    while True:
        prompt=str(input("Which operation you want to preform select: \n To Add_Item enter 1 \n To Update item quantity enter 2 \n To Remove item enter 3 \n To Display All Items enter 4 \n Or press 'Done'to Exit ").lower().strip())
        items_input:str="Enter Item Name: "
        quantity_input="Enter Item Quantity"
        if prompt =="1":
            item=str(input(items_input))
            quantity=int(input(quantity_input))
            inventory.add_items(item,quantity)
        elif prompt=="2":
            item=str(input(items_input))
            quantity=int(input(quantity_input))
            inventory.update_quantity(item,quantity)
        elif prompt=="3":
            item=str(input(items_input))
            inventory.del_item(item)
        elif prompt=="4":
            inventory.display_inventory()
        elif prompt=="done":
            print("Exiting The System........")
            break
        else:
            print("Invalid Input!")
            




if __name__=="__main__":
    main()
# Out:
# Item: abcd is Added with quantity: 123
# Invalid Input!
# Invalid Input!
# abcd is already exists in inventory
# Store Inventory
#  -abcd : 123
# Store Inventory
#  -abcd : 123
# Item: abcd is updated quantity to 678
# Store Inventory
#  -abcd : 678
# Item: abcd deleted successfully
# Exiting The System........

# %%
class Task:
    def __init__(self,task_id,name,description):
        self.task_id=task_id
        self.name=name
        self.description=description
        self.completed=False

    def mark_completed(self,):
       self.completed=True

    def __str__(self):
        status= "Completed" if self.completed==
