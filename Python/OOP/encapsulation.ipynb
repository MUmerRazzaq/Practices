# %% [markdown]
# Encapsulation — Bank Account
#
#  -Create a BankAccount class with:
#
#     Private attribute __balance.
#
#     Methods to deposit, withdraw, and check balance.
#
#     Validation so balance never goes negative.
#
#     -Practice using getter and setter methods.

# %%
class Bank_account:
    def __init__(self, balance):

        self.__balance = balance

    def chk_balance(self):
        return self.__balance
    
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            return f"Deposited: {amount}. New balance: {self.__balance}"
        else:
            return "Deposit amount must be positive."
        
    def withdraw(self, amount):
        if amount > 0:
            if self.__balance >= amount:
                self.__balance -= amount
                return f"Withdrew: {amount}. New balance: {self.__balance}"
            else:
                return "Insufficient funds for this withdrawal."
        else:
            return "Withdrawal amount must be positive."

# %%
acc = Bank_account(1000)
acc.chk_balance()
acc.deposit(500) 
acc.withdraw(100)
acc.withdraw(1500)
# Out:
# 'Insufficient funds for this withdrawal.'

# %% [markdown]
# Encapsulation — Student Record
#
#     Create a Student class with private attributes __name and __marks.
#
#     Add a method to update marks (only if valid 0–100).
#
#     Add a method to check if the student is passing or failing.

# %%
class Student:
    def __init__(self, name, marks):
        self.__name = name
        self.__marks = marks

    def update_marks(self, new_marks):
        if 0 <= new_marks <= 100:
            self.__marks = new_marks
            return f"Marks updated to: {self.__marks}"
        else:
            return "Invalid marks. Must be between 0 and 100."
        
    def is_passing(self):
        return self.__marks >= 40

# %%
student = Student("John Doe", 85)

# %%
student.is_passing()
# Out:
# True

# %%
student.update_marks(39)
student.is_passing()  # Update marks to 90
# Out:
# False
